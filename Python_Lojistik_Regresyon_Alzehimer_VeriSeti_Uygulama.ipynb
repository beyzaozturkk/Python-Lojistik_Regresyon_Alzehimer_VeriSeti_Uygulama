# %% [markdown]
# BEYZA ÖZTÜRK

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d0f13384-e886-447e-bc64-c9c2bcf4eef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0f13384-e886-447e-bc64-c9c2bcf4eef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
alzheimers=pd.read_csv("alzheimers_disease_data.csv")
alzheimers.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
alzheimers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
alzheimers.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %%
for col in alzheimers.columns:
  print(f"Sütun:{col}")
  print(alzheimers[col].unique())
# Out:
# Sütun:PatientID
# [4751 4752 4753 ... 6897 6898 6899]
# Sütun:Age
# [73 89 74 86 68 75 72 87 78 84 64 69 63 65 82 77 71 83 79 67 66 70 85 60
#  88 62 81 61 80 90 76]
# Sütun:Gender
# [0 1]
# Sütun:Ethnicity
# [0 3 1 2]
# Sütun:EducationLevel
# [2 0 1 3]
# Sütun:BMI
# [22.92774923 26.82768119 17.79588244 ... 15.47647896 15.29991122
#  33.28973831]
# Sütun:Smoking
# [0 1]
# Sütun:AlcoholConsumption
# [13.29721773  4.54252382 19.55508453 ...  4.59467018  8.67450518
#   7.89070315]
# Sütun:PhysicalActivity
# [6.32711247 7.61988454 7.84498779 ... 9.88600229 6.35428175 6.57099338]
# Sütun:DietQuality
# [1.34721431 0.51876714 1.82633466 ... 8.12002455 1.26342749 7.94140388]
# Sütun:SleepQuality
# [9.02567867 7.15129274 9.67357416 ... 5.76946355 8.32287396 9.87871052]
# Sütun:FamilyHistoryAlzheimers
# [0 1]
# Sütun:CardiovascularDisease
# [0 1]
# Sütun:Diabetes
# [1 0]
# Sütun:Depression
# [1 0]
# Sütun:HeadInjury
# [0 1]
# Sütun:Hypertension
# [0 1]
# Sütun:SystolicBP
# ...

# %%
alzheimers1 = alzheimers.drop(["PatientID","DoctorInCharge"], axis=1)

# %%
alzheimers1.describe()
# Out:
#                Age       Gender    Ethnicity  EducationLevel          BMI  \
# count  2149.000000  2149.000000  2149.000000     2149.000000  2149.000000
# mean     74.908795     0.506282     0.697534        1.286645    27.655697
# std       8.990221     0.500077     0.996128        0.904527     7.217438
# min      60.000000     0.000000     0.000000        0.000000    15.008851
# 25%      67.000000     0.000000     0.000000        1.000000    21.611408
# 50%      75.000000     1.000000     0.000000        1.000000    27.823924
# 75%      83.000000     1.000000     1.000000        2.000000    33.869778
# max      90.000000     1.000000     3.000000        3.000000    39.992767
#
#            Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  \
# count  2149.000000         2149.000000       2149.000000  2149.000000
# mean      0.288506           10.039442          4.920202     4.993138
# std       0.453173            5.757910          2.857191     2.909055
# ...

# %%
import matplotlib.pyplot as plt

# %%
colors=["pink","lightblue","orange","darkred"]
def bar_plot (variable):
  var=alzheimers1[variable]
  varValue=var.value_counts()
  plt.figure(figsize=(9,3))
  plt.bar(varValue.index,varValue,color=colors)
  plt.xticks(varValue.index,varValue.index.values)
  plt.ylabel("Frequency")
  plt.title(variable)

  print("{}\n{}".format(variable,varValue))
  plt.show()

# %%
category1=["Gender","Ethnicity","EducationLevel","Smoking","FamilyHistoryAlzheimers",
           "CardiovascularDisease","Diabetes","Depression","HeadInjury","Hypertension",
           "MemoryComplaints","BehavioralProblems","Confusion","Disorientation",
           "PersonalityChanges","DifficultyCompletingTasks","Forgetfulness","Diagnosis"]

for c in category1:
  bar_plot(c)
# Out:
# Gender
# Gender
# 1    1088
# 0    1061
# Name: count, dtype: int64
# Ethnicity
# Ethnicity
# 0    1278
# 1     454
# 3     211
# 2     206
# Name: count, dtype: int64
# EducationLevel
# EducationLevel
# 1    854
# 2    636
# 0    446
# 3    213
# Name: count, dtype: int64
# Smoking
# Smoking
# 0    1529
# 1     620
# Name: count, dtype: int64
# FamilyHistoryAlzheimers
# FamilyHistoryAlzheimers
# 0    1607
# 1     542
# Name: count, dtype: int64
# CardiovascularDisease
# CardiovascularDisease
# 0    1839
# 1     310
# Name: count, dtype: int64
# Diabetes
# Diabetes
# 0    1825
# 1     324
# Name: count, dtype: int64
# Depression
# Depression
# 0    1718
# 1     431
# Name: count, dtype: int64
# HeadInjury
# HeadInjury
# 0    1950
# 1     199
# Name: count, dtype: int64
# Hypertension
# Hypertension
# 0    1829
# 1     320
# Name: count, dtype: int64
# MemoryComplaints
# MemoryComplaints
# 0    1702
# 1     447
# Name: count, dtype: int64
# BehavioralProblems
# BehavioralProblems
# ...

# %%
def hist_plot(variable):
  plt.figure(figsize=(7,3))
  plt.hist(alzheimers1[variable],bins=50,color="darkred")
  plt.xlabel(variable)
  plt.ylabel("Frequency")
  plt.title("{}distribution with hist".format(variable))
  plt.show()

# %%
num_list=["Age","BMI","AlcoholConsumption","PhysicalActivity","DietQuality",
          "SleepQuality","SystolicBP","DiastolicBP","CholesterolTotal","CholesterolLDL",
          "CholesterolHDL","CholesterolTriglycerides","MMSE","FunctionalAssessment","ADL"]
for n in num_list:
  hist_plot(n)

# %%
from collections import Counter # Import the Counter class from collections module

def detect_outliers(alzheimers1,features):
  outlier_indices=[]

  for c in features:
    Q1=np.percentile(alzheimers1[c],25)
    Q3=np.percentile(alzheimers1[c],75)
    IQR=Q3-Q1
    outlier_step=1.5*IQR
    # Changed '/' to '|' to combine conditions with logical OR
    outlier_list_col=alzheimers1[(alzheimers1[c]<Q1-outlier_step) | (alzheimers1[c]>Q3+outlier_step)].index
    outlier_indices.extend(outlier_list_col)
  outlier_indices=Counter(outlier_indices) # Now Counter is defined and can be used
  multiple_outliers=list(i for i,v in outlier_indices.items()if v>2)

  return multiple_outliers

# %%
import numpy as np

# %%
alzheimers1.loc[detect_outliers(alzheimers1,["Age","BMI","AlcoholConsumption","PhysicalActivity","DietQuality",
                                             "SleepQuality","SystolicBP","DiastolicBP","CholesterolTotal","CholesterolLDL",
                                             "CholesterolHDL","CholesterolTriglycerides","MMSE","FunctionalAssessment","ADL"])]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Ethnicity, EducationLevel, BMI, Smoking, AlcoholConsumption, PhysicalActivity, DietQuality, SleepQuality, FamilyHistoryAlzheimers, CardiovascularDisease, Diabetes, Depression, HeadInjury, Hypertension, SystolicBP, DiastolicBP, CholesterolTotal, CholesterolLDL, CholesterolHDL, CholesterolTriglycerides, MMSE, FunctionalAssessment, MemoryComplaints, BehavioralProblems, ADL, Confusion, Disorientation, PersonalityChanges, DifficultyCompletingTasks, Forgetfulness, Diagnosis]
# Index: []
#
# [0 rows x 33 columns]

# %%
import seaborn as sns
list1=["BMI","AlcoholConsumption","PhysicalActivity","DietQuality","SleepQuality","SystolicBP","DiastolicBP","CholesterolTotal","CholesterolLDL",
          "CholesterolHDL","CholesterolTriglycerides","MMSE","FunctionalAssessment","ADL"]
plt.figure(figsize=(10,10))
sns.heatmap(alzheimers1[list1].corr(),annot=True,fmt=".2f",cmap="RdBu")
plt.show()

# %%
alzheimers1[["Gender","Diagnosis"]].groupby(["Gender"],as_index=False).mean().sort_values(by="Diagnosis",ascending=False)
#as_index=False:Gender,indeks olarak kullanılmaz.
#ascending=False: Sıralama, azalan sırayla yapılır.
# Out:
#    Gender  Diagnosis
# 0       0   0.363808
# 1       1   0.343750

# %%
alzheimers1[["EducationLevel","Diagnosis"]].groupby(["EducationLevel"],as_index=False).mean().sort_values(by="Diagnosis",ascending=False)
# Out:
#    EducationLevel  Diagnosis
# 0               0   0.390135
# 1               1   0.353630
# 2               2   0.341195
# 3               3   0.314554

# %%
alzheimers1[["Ethnicity","Diagnosis"]].groupby(["Ethnicity"],as_index=False).mean().sort_values(by="Diagnosis",ascending=False)
# Out:
#    Ethnicity  Diagnosis
# 3          3   0.317536
# 1          1   0.321586
# 0          0   0.362285
# 2          2   0.407767

# %%
g=sns.catplot(x="Gender",y="Diagnosis",data=alzheimers1,kind="bar",color="red")
g.set_ylabels("Disease probability")
plt.show()

# %%
g=sns.catplot(x="Ethnicity",y="Diagnosis",data=alzheimers1,kind="bar",color="green")
g.set_ylabels("Disease probability")
plt.show()

# %%
g=sns.catplot(x="EducationLevel",y="Diagnosis",data=alzheimers1,kind="bar",color="orange")
g.set_ylabels("Disease probability")
plt.show()

# %% [markdown]
# **LOJİSTİK REGRESYON**

# %%
from sklearn.model_selection import train_test_split

# %%
X=alzheimers1.drop(["Diagnosis"],axis=1)
Y=alzheimers1["Diagnosis"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
y_pred=log_reg.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
conf_mat=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",conf_mat)
# Out:
# Confusion Matrix:
#  [[234  33]
#  [ 57 106]]

# %%
acc_log_train=round(log_reg.score(X_train,y_train)*100,2)
acc_log_test=round(log_reg.score(X_test,y_test)*100,2)
print("The train accuracy score:%{}".format(acc_log_train))
print("The test accuracy score:%{}".format(acc_log_test))
# Out:
# The train accuracy score:%82.43
# The test accuracy score:%79.07
